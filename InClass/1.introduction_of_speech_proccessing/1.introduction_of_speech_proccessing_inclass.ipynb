# %% [markdown]
# # Audio Formats
# *   mp3
# *   flac
# *   wav

# %% [markdown]
# ![what-is-mp3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![flac-icon.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Download-WAV-Files.webp](data:image/webp;base64,...)

# %% [markdown]
# # Audio Signal Parameters
# * number of channels
# * sample width (Bytes)
# * framerate / sample rate (44100 KHz)
# * number of frames
# * value of frames

# %%
import wave

# %%
obj = wave.open('test.wav','rb')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
