# %% [markdown]
# ## [AssemblyAi](https://www.assemblyai.com/)

# %% [markdown]
# ![assemplyai.png](data:image/png;base64,...)

# %% [markdown]
# ![assmb.PNG](data:image/png;base64,...)

# %%
with open('assemblyai.txt') as f:
  API_KEY = f.read()

# %%
import requests
